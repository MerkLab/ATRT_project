# %%
# !mageck
# Out:
# usage: mageck [-h] [-v] {count,test,pathway,plot,mle} ...
#
# mageck: performs sgRNA, gene and pathway analysis on CRISPR-Cas9 screening
# data.
#
# positional arguments:
#   {count,test,pathway,plot,mle}
#                         commands to run mageck
#     count               Collecting read counts from fastq files.
#     test                Perform statistical test from a given count table
#                         (generated by count command).
#     pathway             Perform significant pathway analysis from gene
#                         rankings generated by the test command.
#     plot                Generating graphics for selected genes.
#     mle                 Perform MLE estimation of gene essentiality.
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -v, --version         show program's version number and exit

# %%
# !mageck mle -h
# Out:
# usage: mageck mle [-h] -k COUNT_TABLE
#                   (-d DESIGN_MATRIX | --day0-label DAY0_LABEL)
#                   [-n OUTPUT_PREFIX] [-i INCLUDE_SAMPLES] [-b BETA_LABELS]
#                   [--control-sgrna CONTROL_SGRNA | --control-gene CONTROL_GENE]
#                   [--cnv-norm CNV_NORM] [--cell-line CELL_LINE]
#                   [--cnv-est CNV_EST] [--debug] [--debug-gene DEBUG_GENE]
#                   [--norm-method {none,median,total,control}]
#                   [--genes-varmodeling GENES_VARMODELING]
#                   [--permutation-round PERMUTATION_ROUND]
#                   [--no-permutation-by-group]
#                   [--max-sgrnapergene-permutation MAX_SGRNAPERGENE_PERMUTATION]
#                   [--remove-outliers] [--threads THREADS]
#                   [--adjust-method {fdr,holm,pounds}]
#                   [--sgrna-efficiency SGRNA_EFFICIENCY]
#                   [--sgrna-eff-name-column SGRNA_EFF_NAME_COLUMN]
# ...

# %%
ls
# Out:
# Calabrese_ATRT_raw_counts_reps.xlsx*   MAGeCK MLE Calabrese Resistance.ipynb
# Calabrese_raw_counts_avg.txt           Results_common_drugshared/
# Design_matrix_common_drugshared.txt    Results_normal_design/
# Design_matrix_normal.txt*

# %% [markdown]
# #Start with comparison for common and drug-shared changes

# %%
# !mageck mle -k Calabrese_raw_counts_avg.txt -d Design_matrix_common_drugshared.txt
# Out:
# INFO  @ Wed, 09 Feb 2022 13:37:02: Parameters: /Users/lab/opt/anaconda3/bin/mageck mle -k Calabrese_raw_counts_avg.txt -d Design_matrix_common_drugshared.txt
# INFO  @ Wed, 09 Feb 2022 13:37:02: Cannot parse design matrix as a string; try to parse it as a file name ...
# INFO  @ Wed, 09 Feb 2022 13:37:02: Design matrix:
# INFO  @ Wed, 09 Feb 2022 13:37:02: [[1. 0. 0.]
# INFO  @ Wed, 09 Feb 2022 13:37:02:  [1. 1. 0.]
# INFO  @ Wed, 09 Feb 2022 13:37:02:  [1. 1. 1.]
# INFO  @ Wed, 09 Feb 2022 13:37:02:  [1. 1. 1.]
# INFO  @ Wed, 09 Feb 2022 13:37:02:  [1. 1. 0.]
# INFO  @ Wed, 09 Feb 2022 13:37:02:  [1. 1. 1.]
# INFO  @ Wed, 09 Feb 2022 13:37:02:  [1. 1. 1.]]
# INFO  @ Wed, 09 Feb 2022 13:37:02: Beta labels:baseline,common,drug
# INFO  @ Wed, 09 Feb 2022 13:37:02: Included samples:Plasmid,BT16_DMSO,BT16_Palbo,BT16_Abema,CHLA06_DMSO,CHLA06_Palbo,CHLA06_Abema
# INFO  @ Wed, 09 Feb 2022 13:37:02: Loaded samples:Plasmid;BT16_DMSO;BT16_Palbo;BT16_Abema;CHLA06_DMSO;CHLA06_Palbo;CHLA06_Abema
# ...

# %%
# !mageck mle -k Calabrese_raw_counts_avg.txt -d Design_matrix_normal.txt
# Out:
# INFO  @ Wed, 09 Feb 2022 14:24:01: Parameters: /Users/lab/opt/anaconda3/bin/mageck mle -k Calabrese_raw_counts_avg.txt -d Design_matrix_normal.txt
# INFO  @ Wed, 09 Feb 2022 14:24:02: Cannot parse design matrix as a string; try to parse it as a file name ...
# INFO  @ Wed, 09 Feb 2022 14:24:02: Design matrix:
# INFO  @ Wed, 09 Feb 2022 14:24:02: [[1. 0. 0. 0. 0. 0. 0.]
# INFO  @ Wed, 09 Feb 2022 14:24:02:  [1. 1. 0. 0. 0. 0. 0.]
# INFO  @ Wed, 09 Feb 2022 14:24:02:  [1. 0. 1. 0. 0. 0. 0.]
# INFO  @ Wed, 09 Feb 2022 14:24:02:  [1. 0. 0. 1. 0. 0. 0.]
# INFO  @ Wed, 09 Feb 2022 14:24:02:  [1. 0. 0. 0. 1. 0. 0.]
# INFO  @ Wed, 09 Feb 2022 14:24:02:  [1. 0. 0. 0. 0. 1. 0.]
# INFO  @ Wed, 09 Feb 2022 14:24:02:  [1. 0. 0. 0. 0. 0. 1.]]
# INFO  @ Wed, 09 Feb 2022 14:24:02: Beta labels:baseline,BT16_DMSO,BT16_Palbo,BT16_Abema,CHLA06_DMSO,CHLA06_Palbo,CHLA06_Abema
# ...

# %%
ls
# Out:
# Calabrese_ATRT_raw_counts_reps.xlsx*   Design_matrix_common_drugshared.txt
# Calabrese_BT16_raw_counts_avg.txt      Design_matrix_normal.txt*
# Calabrese_CHLA06_raw_counts_avg.txt    MAGeCK MLE Calabrese Resistance.ipynb
# Calabrese_raw_counts_avg.txt           Results_common_drugshared/
# Design_matrix_BT16_Drugs_vs_DMSO.txt*  Results_normal_design/
# Design_matrix_CHLA06_drug_vs_DMSO.txt*

# %%
# !mageck mle -k Calabrese_BT16_raw_counts_avg.txt -d Design_matrix_BT16_Drugs_vs_DMSO.txt
# Out:
# INFO  @ Wed, 09 Feb 2022 15:13:52: Parameters: /Users/lab/opt/anaconda3/bin/mageck mle -k Calabrese_BT16_raw_counts_avg.txt -d Design_matrix_BT16_Drugs_vs_DMSO.txt
# INFO  @ Wed, 09 Feb 2022 15:13:52: Cannot parse design matrix as a string; try to parse it as a file name ...
# INFO  @ Wed, 09 Feb 2022 15:13:52: Design matrix:
# INFO  @ Wed, 09 Feb 2022 15:13:52: [[1. 0. 0.]
# INFO  @ Wed, 09 Feb 2022 15:13:52:  [1. 1. 0.]
# INFO  @ Wed, 09 Feb 2022 15:13:52:  [1. 0. 1.]]
# INFO  @ Wed, 09 Feb 2022 15:13:52: Beta labels:baseline,BT16_Palbo,BT16_Abema
# INFO  @ Wed, 09 Feb 2022 15:13:52: Included samples:BT16_DMSO,BT16_Palbo,BT16_Abema
# INFO  @ Wed, 09 Feb 2022 15:13:52: Loaded samples:BT16_DMSO;BT16_Palbo;BT16_Abema
# INFO  @ Wed, 09 Feb 2022 15:13:52: Sample index: 0;1;2
# INFO  @ Wed, 09 Feb 2022 15:13:52: Loaded 18885 genes.
# INFO  @ Wed, 09 Feb 2022 15:13:53: Final size factor: 1.0749876876394795 0.947493040992903 0.9877776304037432
# ...

# %%
ls
# Out:
# Calabrese_ATRT_raw_counts_reps.xlsx*   Design_matrix_common_drugshared.txt
# Calabrese_BT16_raw_counts_avg.txt      Design_matrix_normal.txt*
# Calabrese_CHLA06_raw_counts_avg.txt    MAGeCK MLE Calabrese Resistance.ipynb
# Calabrese_raw_counts_avg.txt           Results_Drugs_vs_DMSO/
# Design_matrix_BT16_Drugs_vs_DMSO.txt*  Results_common_drugshared/
# Design_matrix_CHLA06_drug_vs_DMSO.txt* Results_normal_design/

# %%
# !mageck mle -k Calabrese_CHLA06_raw_counts_avg.txt -d Design_matrix_CHLA06_drug_vs_DMSO.txt
# Out:
# INFO  @ Wed, 09 Feb 2022 17:00:34: Parameters: /Users/lab/opt/anaconda3/bin/mageck mle -k Calabrese_CHLA06_raw_counts_avg.txt -d Design_matrix_CHLA06_drug_vs_DMSO.txt
# INFO  @ Wed, 09 Feb 2022 17:00:34: Cannot parse design matrix as a string; try to parse it as a file name ...
# INFO  @ Wed, 09 Feb 2022 17:00:34: Design matrix:
# INFO  @ Wed, 09 Feb 2022 17:00:34: [[1. 0. 0.]
# INFO  @ Wed, 09 Feb 2022 17:00:34:  [1. 1. 0.]
# INFO  @ Wed, 09 Feb 2022 17:00:34:  [1. 0. 1.]]
# INFO  @ Wed, 09 Feb 2022 17:00:34: Beta labels:baseline,CHLA06_Palbo,CHLA06_Abema
# INFO  @ Wed, 09 Feb 2022 17:00:34: Included samples:CHLA06_DMSO,CHLA06_Palbo,CHLA06_Abema
# INFO  @ Wed, 09 Feb 2022 17:00:34: Loaded samples:CHLA06_DMSO;CHLA06_Palbo;CHLA06_Abema
# INFO  @ Wed, 09 Feb 2022 17:00:34: Sample index: 0;1;2
# INFO  @ Wed, 09 Feb 2022 17:00:34: Loaded 18885 genes.
# INFO  @ Wed, 09 Feb 2022 17:00:35: Final size factor: 0.6310100587140299 0.9941356847527045 1.6226340322148314
# ...

# %%
ls
# Out:
# Calabrese_ATRT_raw_counts_reps.xlsx*   Design_matrix_normal.txt*
# Calabrese_BT16_raw_counts_avg.txt      MAGeCK MLE Calabrese Resistance.ipynb
# Calabrese_CHLA06_raw_counts_avg.txt    Results_Drugs_vs_DMSO/
# Calabrese_raw_counts_avg.txt           Results_common_drugshared/
# Design_matrix_BT16_Drugs_vs_DMSO.txt*  Results_normal_design/
# Design_matrix_BT16_drug_common.txt     sample1.gene_summary.txt
# Design_matrix_CHLA06_drug_common.txt   sample1.log
# Design_matrix_CHLA06_drug_vs_DMSO.txt* sample1.sgrna_summary.txt
# Design_matrix_common_drugshared.txt

# %%
# !mageck mle -k Calabrese_BT16_raw_counts_avg.txt -d Design_matrix_BT16_drug_common.txt
# Out:
# INFO  @ Fri, 08 Apr 2022 08:52:26: Parameters: /Users/lab/opt/anaconda3/bin/mageck mle -k Calabrese_BT16_raw_counts_avg.txt -d Design_matrix_BT16_drug_common.txt
# INFO  @ Fri, 08 Apr 2022 08:52:26: Cannot parse design matrix as a string; try to parse it as a file name ...
# INFO  @ Fri, 08 Apr 2022 08:52:26: Design matrix:
# INFO  @ Fri, 08 Apr 2022 08:52:26: [[1. 0.]
# INFO  @ Fri, 08 Apr 2022 08:52:26:  [1. 1.]
# INFO  @ Fri, 08 Apr 2022 08:52:26:  [1. 1.]]
# INFO  @ Fri, 08 Apr 2022 08:52:26: Beta labels:baseline,BT16_drug_common
# INFO  @ Fri, 08 Apr 2022 08:52:26: Included samples:BT16_DMSO,BT16_Palbo,BT16_Abema
# INFO  @ Fri, 08 Apr 2022 08:52:26: Loaded samples:BT16_DMSO;BT16_Palbo;BT16_Abema
# INFO  @ Fri, 08 Apr 2022 08:52:26: Sample index: 0;1;2
# INFO  @ Fri, 08 Apr 2022 08:52:26: Loaded 18885 genes.
# INFO  @ Fri, 08 Apr 2022 08:52:27: Final size factor: 1.0749876876394795 0.947493040992903 0.9877776304037432
# ...

# %%
ls
# Out:
# Calabrese_ATRT_raw_counts_reps.xlsx*   Design_matrix_normal.txt*
# Calabrese_BT16_raw_counts_avg.txt      MAGeCK MLE Calabrese Resistance.ipynb
# Calabrese_CHLA06_raw_counts_avg.txt    Results_Drugs_vs_DMSO/
# Calabrese_raw_counts_avg.txt           Results_common_drugshared_vs_plasmid/
# Design_matrix_BT16_Drugs_vs_DMSO.txt*  Results_normal_design/
# Design_matrix_BT16_drug_common.txt     sample1.gene_summary.txt
# Design_matrix_CHLA06_drug_common.txt   sample1.log
# Design_matrix_CHLA06_drug_vs_DMSO.txt* sample1.sgrna_summary.txt
# Design_matrix_common_drugshared.txt

# %%
# !mageck mle -k Calabrese_CHLA06_raw_counts_avg.txt -d Design_matrix_CHLA06_drug_common.txt
# Out:
# INFO  @ Fri, 08 Apr 2022 09:02:48: Parameters: /Users/lab/opt/anaconda3/bin/mageck mle -k Calabrese_CHLA06_raw_counts_avg.txt -d Design_matrix_CHLA06_drug_common.txt
# INFO  @ Fri, 08 Apr 2022 09:02:49: Cannot parse design matrix as a string; try to parse it as a file name ...
# INFO  @ Fri, 08 Apr 2022 09:02:49: Design matrix:
# INFO  @ Fri, 08 Apr 2022 09:02:49: [[1. 0.]
# INFO  @ Fri, 08 Apr 2022 09:02:49:  [1. 1.]
# INFO  @ Fri, 08 Apr 2022 09:02:49:  [1. 1.]]
# INFO  @ Fri, 08 Apr 2022 09:02:49: Beta labels:baseline,CHLA06_drug_common
# INFO  @ Fri, 08 Apr 2022 09:02:49: Included samples:CHLA06_DMSO,CHLA06_Palbo,CHLA06_Abema
# INFO  @ Fri, 08 Apr 2022 09:02:49: Loaded samples:CHLA06_DMSO;CHLA06_Palbo;CHLA06_Abema
# INFO  @ Fri, 08 Apr 2022 09:02:49: Sample index: 0;1;2
# INFO  @ Fri, 08 Apr 2022 09:02:49: Loaded 18885 genes.
# INFO  @ Fri, 08 Apr 2022 09:02:49: Final size factor: 0.6310100587140299 0.9941356847527045 1.6226340322148314
# ...

# %%
ls
# Out:
# Calabrese_ATRT_raw_counts_reps.xlsx*
# Calabrese_BT16_raw_counts_avg.txt
# Calabrese_BT16_raw_counts_drugs_and_plasmid.txt
# Calabrese_CHLA06_raw_counts_avg.txt
# Calabrese_CHLA06_raw_counts_drugs_and_plasmid.txt
# Calabrese_raw_counts_avg.txt
# Design_matrix_BT16_Drugs_vs_DMSO.txt*
# Design_matrix_BT16_drug_common.txt
# Design_matrix_BT16_drug_common_vs_plasmid.txt
# Design_matrix_CHLA06_drug_common.txt
# Design_matrix_CHLA06_drug_common_vs_plasmid.txt
# Design_matrix_CHLA06_drug_vs_DMSO.txt*
# Design_matrix_common_drugshared.txt
# Design_matrix_normal.txt*
# MAGeCK MLE Calabrese Resistance.ipynb
# Results_Drugs_vs_DMSO/
# Results_common_drugshared_vs_plasmid/
# Results_normal_design/

# %%
# !mageck mle -h
# Out:
# usage: mageck mle [-h] -k COUNT_TABLE
#                   (-d DESIGN_MATRIX | --day0-label DAY0_LABEL)
#                   [-n OUTPUT_PREFIX] [-i INCLUDE_SAMPLES] [-b BETA_LABELS]
#                   [--control-sgrna CONTROL_SGRNA | --control-gene CONTROL_GENE]
#                   [--cnv-norm CNV_NORM] [--cell-line CELL_LINE]
#                   [--cnv-est CNV_EST] [--debug] [--debug-gene DEBUG_GENE]
#                   [--norm-method {none,median,total,control}]
#                   [--genes-varmodeling GENES_VARMODELING]
#                   [--permutation-round PERMUTATION_ROUND]
#                   [--no-permutation-by-group]
#                   [--max-sgrnapergene-permutation MAX_SGRNAPERGENE_PERMUTATION]
#                   [--remove-outliers] [--threads THREADS]
#                   [--adjust-method {fdr,holm,pounds}]
#                   [--sgrna-efficiency SGRNA_EFFICIENCY]
#                   [--sgrna-eff-name-column SGRNA_EFF_NAME_COLUMN]
# ...

# %%
# !mageck mle -k Calabrese_BT16_raw_counts_drugs_and_plasmid.txt -d Design_matrix_BT16_drug_common_vs_plasmid.txt --control-sgrna Calabrese_nontargeting.txt
# Out:
# INFO  @ Thu, 19 May 2022 17:22:01: Parameters: /Users/lab/opt/anaconda3/bin/mageck mle -k Calabrese_BT16_raw_counts_drugs_and_plasmid.txt -d Design_matrix_BT16_drug_common_vs_plasmid.txt --control-sgrna Calabrese_nontargeting.txt
# INFO  @ Thu, 19 May 2022 17:22:02: Cannot parse design matrix as a string; try to parse it as a file name ...
# INFO  @ Thu, 19 May 2022 17:22:02: Design matrix:
# INFO  @ Thu, 19 May 2022 17:22:02: [[1. 0.]
# INFO  @ Thu, 19 May 2022 17:22:02:  [1. 1.]
# INFO  @ Thu, 19 May 2022 17:22:02:  [1. 1.]]
# INFO  @ Thu, 19 May 2022 17:22:02: Beta labels:baseline,BT16_drug_common_vs_plasmid
# INFO  @ Thu, 19 May 2022 17:22:02: Included samples:Plasmid,BT16_Palbo,BT16_Abema
# INFO  @ Thu, 19 May 2022 17:22:02: Loaded samples:Plasmid;BT16_Palbo;BT16_Abema
# INFO  @ Thu, 19 May 2022 17:22:02: Sample index: 0;1;2
# INFO  @ Thu, 19 May 2022 17:22:02: Loaded 18885 genes.
# INFO  @ Thu, 19 May 2022 17:22:02: 496 out of 496 control sgRNAs are found in count table.
# ...

# %%
ls
# Out:
# Calabrese_ATRT_raw_counts_reps.xlsx*
# Calabrese_BT16_raw_counts_avg.txt
# Calabrese_BT16_raw_counts_drugs_and_plasmid.txt
# Calabrese_CHLA06_raw_counts_avg.txt
# Calabrese_CHLA06_raw_counts_drugs_and_plasmid.txt
# Calabrese_nontargeting.txt*
# Calabrese_raw_counts_avg.txt
# Design_matrix_BT16_Drugs_vs_DMSO.txt*
# Design_matrix_BT16_drug_common.txt
# Design_matrix_BT16_drug_common_vs_plasmid.txt
# Design_matrix_CHLA06_drug_common.txt
# Design_matrix_CHLA06_drug_common_vs_plasmid.txt
# Design_matrix_CHLA06_drug_vs_DMSO.txt*
# Design_matrix_common_drugshared.txt
# Design_matrix_normal.txt*
# MAGeCK MLE Calabrese Resistance.ipynb
# Results_Drugs_vs_DMSO/
# Results_common_drugshared_vs_plasmid/
# Results_drugs_per_cell_line_vs_plasmid/
# Results_normal_design/

# %%
# !mageck mle -k Calabrese_CHLA06_raw_counts_drugs_and_plasmid.txt -d Design_matrix_CHLA06_drug_common_vs_plasmid.txt --control-sgrna Calabrese_nontargeting.txt
# Out:
# INFO  @ Thu, 19 May 2022 18:18:23: Parameters: /Users/lab/opt/anaconda3/bin/mageck mle -k Calabrese_CHLA06_raw_counts_drugs_and_plasmid.txt -d Design_matrix_CHLA06_drug_common_vs_plasmid.txt --control-sgrna Calabrese_nontargeting.txt
# INFO  @ Thu, 19 May 2022 18:18:23: Cannot parse design matrix as a string; try to parse it as a file name ...
# INFO  @ Thu, 19 May 2022 18:18:23: Design matrix:
# INFO  @ Thu, 19 May 2022 18:18:23: [[1. 0.]
# INFO  @ Thu, 19 May 2022 18:18:23:  [1. 1.]
# INFO  @ Thu, 19 May 2022 18:18:23:  [1. 1.]]
# INFO  @ Thu, 19 May 2022 18:18:23: Beta labels:baseline,CHLA06_drug_common_vs_plasmid
# INFO  @ Thu, 19 May 2022 18:18:23: Included samples:Plasmid,CHLA06_Palbo,CHLA06_Abema
# INFO  @ Thu, 19 May 2022 18:18:23: Loaded samples:Plasmid;CHLA06_Palbo;CHLA06_Abema
# INFO  @ Thu, 19 May 2022 18:18:23: Sample index: 0;1;2
# INFO  @ Thu, 19 May 2022 18:18:23: Loaded 18885 genes.
# ...
