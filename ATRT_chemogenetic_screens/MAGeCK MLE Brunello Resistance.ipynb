# %%
ls
# Out:
# Brunello_corrected_counts.csv*        MAGeCK MLE Brunello Resistance.ipynb
# Design_matrix.txt*

# %%
# !mageck
# Out:
# usage: mageck [-h] [-v] {count,test,pathway,plot,mle} ...
#
# mageck: performs sgRNA, gene and pathway analysis on CRISPR-Cas9 screening
# data.
#
# positional arguments:
#   {count,test,pathway,plot,mle}
#                         commands to run mageck
#     count               Collecting read counts from fastq files.
#     test                Perform statistical test from a given count table
#                         (generated by count command).
#     pathway             Perform significant pathway analysis from gene
#                         rankings generated by the test command.
#     plot                Generating graphics for selected genes.
#     mle                 Perform MLE estimation of gene essentiality.
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -v, --version         show program's version number and exit

# %%
# !mageck mle -h
# Out:
# usage: mageck mle [-h] -k COUNT_TABLE
#                   (-d DESIGN_MATRIX | --day0-label DAY0_LABEL)
#                   [-n OUTPUT_PREFIX] [-i INCLUDE_SAMPLES] [-b BETA_LABELS]
#                   [--control-sgrna CONTROL_SGRNA | --control-gene CONTROL_GENE]
#                   [--cnv-norm CNV_NORM] [--cell-line CELL_LINE]
#                   [--cnv-est CNV_EST] [--debug] [--debug-gene DEBUG_GENE]
#                   [--norm-method {none,median,total,control}]
#                   [--genes-varmodeling GENES_VARMODELING]
#                   [--permutation-round PERMUTATION_ROUND]
#                   [--no-permutation-by-group]
#                   [--max-sgrnapergene-permutation MAX_SGRNAPERGENE_PERMUTATION]
#                   [--remove-outliers] [--threads THREADS]
#                   [--adjust-method {fdr,holm,pounds}]
#                   [--sgrna-efficiency SGRNA_EFFICIENCY]
#                   [--sgrna-eff-name-column SGRNA_EFF_NAME_COLUMN]
# ...

# %%
ls
# Out:
# Brunello_corrected_counts.csv*        MAGeCK MLE Brunello Resistance.ipynb
# Brunello_corrected_counts.txt*        control_sgRNA.txt*
# Design_matrix.txt*                    sample1.log

# %%
# !mageck mle -k Brunello_corrected_counts.txt -d Design_matrix.txt --control-sgrna control_sgRNA.txt --norm-method none
# Out:
# INFO  @ Mon, 24 Jan 2022 11:37:07: Parameters: /Users/lab/opt/anaconda3/bin/mageck mle -k Brunello_corrected_counts.txt -d Design_matrix.txt --control-sgrna control_sgRNA.txt --norm-method none
# INFO  @ Mon, 24 Jan 2022 11:37:07: Cannot parse design matrix as a string; try to parse it as a file name ...
# INFO  @ Mon, 24 Jan 2022 11:37:07: Design matrix:
# INFO  @ Mon, 24 Jan 2022 11:37:07: [[1. 0. 0. 0. 0. 0. 0.]
# INFO  @ Mon, 24 Jan 2022 11:37:07:  [1. 1. 0. 0. 0. 0. 0.]
# INFO  @ Mon, 24 Jan 2022 11:37:07:  [1. 0. 1. 0. 0. 0. 0.]
# INFO  @ Mon, 24 Jan 2022 11:37:07:  [1. 0. 0. 1. 0. 0. 0.]
# INFO  @ Mon, 24 Jan 2022 11:37:07:  [1. 0. 0. 0. 1. 0. 0.]
# INFO  @ Mon, 24 Jan 2022 11:37:07:  [1. 0. 0. 0. 0. 1. 0.]
# INFO  @ Mon, 24 Jan 2022 11:37:07:  [1. 0. 0. 0. 0. 0. 1.]]
# INFO  @ Mon, 24 Jan 2022 11:37:07: Beta labels:baseline,BT16_DMSO,BT16_Palbo,BT16_Abema,CHLA06_DMSO,CHLA06_Palbo,CHLA06_Abema
# ...

# %%
ls
# Out:
# Brunello_corrected_counts.txt*        MLE.log
# Brunello_raw_counts.txt*              MLE.sgrna_summary.txt
# Design_matrix.txt*                    control_sgRNA.txt*
# MAGeCK MLE Brunello Resistance.ipynb  sample1.log
# MLE.gene_summary.txt

# %%
# !mageck mle -k Brunello_raw_counts.txt -d Design_matrix.txt --control-sgrna control_sgRNA.txt
# Out:
# INFO  @ Mon, 24 Jan 2022 20:19:03: Parameters: /Users/lab/opt/anaconda3/bin/mageck mle -k Brunello_raw_counts.txt -d Design_matrix.txt --control-sgrna control_sgRNA.txt
# INFO  @ Mon, 24 Jan 2022 20:19:03: Cannot parse design matrix as a string; try to parse it as a file name ...
# INFO  @ Mon, 24 Jan 2022 20:19:03: Design matrix:
# INFO  @ Mon, 24 Jan 2022 20:19:03: [[1. 0. 0. 0. 0. 0. 0.]
# INFO  @ Mon, 24 Jan 2022 20:19:03:  [1. 1. 0. 0. 0. 0. 0.]
# INFO  @ Mon, 24 Jan 2022 20:19:03:  [1. 0. 1. 0. 0. 0. 0.]
# INFO  @ Mon, 24 Jan 2022 20:19:03:  [1. 0. 0. 1. 0. 0. 0.]
# INFO  @ Mon, 24 Jan 2022 20:19:03:  [1. 0. 0. 0. 1. 0. 0.]
# INFO  @ Mon, 24 Jan 2022 20:19:03:  [1. 0. 0. 0. 0. 1. 0.]
# INFO  @ Mon, 24 Jan 2022 20:19:03:  [1. 0. 0. 0. 0. 0. 1.]]
# INFO  @ Mon, 24 Jan 2022 20:19:03: Beta labels:baseline,BT16_DMSO,BT16_Palbo,BT16_Abema,CHLA06_DMSO,CHLA06_Palbo,CHLA06_Abema
# ...

# %%
ls
# Out:
# Brunello_corrected_counts.txt*
# Brunello_corrected_counts_BT16.txt*
# Brunello_corrected_counts_CHLA06.txt*
# Brunello_raw_counts.txt*
# Design_matrix_BT16_Drugs_vs_DMSO.txt*
# Design_matrix_CHLA06_drug_vs_DMSO.txt*
# Design_matrix_normal.txt*
# MAGeCK MLE Brunello Resistance.ipynb
# Results_corrected_counts_normal_design/
# Results_uncorrected_raw_counts_normal_design/
# control_sgRNA.txt*

# %%
# !mageck mle -k Brunello_corrected_counts_BT16.txt -d Design_matrix_BT16_Drugs_vs_DMSO.txt --control-sgrna control_sgRNA.txt --norm-method none
# Out:
# INFO  @ Mon, 24 Jan 2022 21:06:52: Parameters: /Users/lab/opt/anaconda3/bin/mageck mle -k Brunello_corrected_counts_BT16.txt -d Design_matrix_BT16_Drugs_vs_DMSO.txt --control-sgrna control_sgRNA.txt --norm-method none
# INFO  @ Mon, 24 Jan 2022 21:06:53: Cannot parse design matrix as a string; try to parse it as a file name ...
# INFO  @ Mon, 24 Jan 2022 21:06:53: Design matrix:
# INFO  @ Mon, 24 Jan 2022 21:06:53: [[1. 0. 0.]
# INFO  @ Mon, 24 Jan 2022 21:06:53:  [1. 1. 0.]
# INFO  @ Mon, 24 Jan 2022 21:06:53:  [1. 0. 1.]]
# INFO  @ Mon, 24 Jan 2022 21:06:53: Beta labels:baseline,BT16_Palbo,BT16_Abema
# INFO  @ Mon, 24 Jan 2022 21:06:53: Included samples:BT16_DMSO,BT16_Palbo,BT16_Abema
# INFO  @ Mon, 24 Jan 2022 21:06:53: Loaded samples:BT16_DMSO;BT16_Palbo;BT16_Abema
# INFO  @ Mon, 24 Jan 2022 21:06:53: Sample index: 0;1;2
# INFO  @ Mon, 24 Jan 2022 21:06:53: Loaded 19105 genes.
# INFO  @ Mon, 24 Jan 2022 21:06:53: 3574 out of 3594 control sgRNAs are found in count table.
# ...

# %%
ls
# Out:
# Brunello_corrected_counts.txt*
# Brunello_corrected_counts_BT16.txt*
# Brunello_corrected_counts_CHLA06.txt*
# Brunello_raw_counts.txt*
# Design_matrix_BT16_Drugs_vs_DMSO.txt*
# Design_matrix_CHLA06_drug_vs_DMSO.txt*
# Design_matrix_normal.txt*
# MAGeCK MLE Brunello Resistance.ipynb
# Results_corrected_counts_Drugs_vs_DMSO_design/
# Results_corrected_counts_normal_design/
# Results_uncorrected_raw_counts_normal_design/
# control_sgRNA.txt*

# %%
# !mageck mle -k Brunello_corrected_counts_CHLA06.txt -d Design_matrix_CHLA06_drug_vs_DMSO.txt --control-sgrna control_sgRNA.txt --norm-method none
# Out:
# INFO  @ Mon, 24 Jan 2022 21:20:41: Parameters: /Users/lab/opt/anaconda3/bin/mageck mle -k Brunello_corrected_counts_CHLA06.txt -d Design_matrix_CHLA06_drug_vs_DMSO.txt --control-sgrna control_sgRNA.txt --norm-method none
# INFO  @ Mon, 24 Jan 2022 21:20:41: Cannot parse design matrix as a string; try to parse it as a file name ...
# INFO  @ Mon, 24 Jan 2022 21:20:41: Design matrix:
# INFO  @ Mon, 24 Jan 2022 21:20:41: [[1. 0. 0.]
# INFO  @ Mon, 24 Jan 2022 21:20:41:  [1. 1. 0.]
# INFO  @ Mon, 24 Jan 2022 21:20:41:  [1. 0. 1.]]
# INFO  @ Mon, 24 Jan 2022 21:20:41: Beta labels:baseline,CHLA06_Palbo,CHLA06_Abema
# INFO  @ Mon, 24 Jan 2022 21:20:41: Included samples:CHLA06_DMSO,CHLA06_Palbo,CHLA06_Abema
# INFO  @ Mon, 24 Jan 2022 21:20:41: Loaded samples:CHLA06_DMSO;CHLA06_Palbo;CHLA06_Abema
# INFO  @ Mon, 24 Jan 2022 21:20:41: Sample index: 0;1;2
# INFO  @ Mon, 24 Jan 2022 21:20:41: Loaded 19105 genes.
# ...

# %%
ls
# Out:
# Brunello_corrected_counts.txt*
# Brunello_corrected_counts_BT16.txt*
# Brunello_corrected_counts_CHLA06.txt*
# Brunello_raw_counts.txt*
# Design_matrix_BT16_Drugs_vs_DMSO.txt*
# Design_matrix_CHLA06_drug_vs_DMSO.txt*
# Design_matrix_common_drugshared.txt
# Design_matrix_normal.txt*
# MAGeCK MLE Brunello Resistance.ipynb
# Results_corrected_counts_Drugs_vs_DMSO_design/
# Results_corrected_counts_normal_design/
# Results_uncorrected_raw_counts_normal_design/
# control_sgRNA.txt*

# %%
# !mageck mle -k Brunello_corrected_counts.txt -d Design_matrix_common_drugshared.txt --control-sgrna control_sgRNA.txt --norm-method none
# Out:
# INFO  @ Tue, 25 Jan 2022 09:41:10: Parameters: /Users/lab/opt/anaconda3/bin/mageck mle -k Brunello_corrected_counts.txt -d Design_matrix_common_drugshared.txt --control-sgrna control_sgRNA.txt --norm-method none
# INFO  @ Tue, 25 Jan 2022 09:41:10: Cannot parse design matrix as a string; try to parse it as a file name ...
# INFO  @ Tue, 25 Jan 2022 09:41:10: Design matrix:
# INFO  @ Tue, 25 Jan 2022 09:41:10: [[1. 0. 0.]
# INFO  @ Tue, 25 Jan 2022 09:41:10:  [1. 1. 0.]
# INFO  @ Tue, 25 Jan 2022 09:41:10:  [1. 1. 1.]
# INFO  @ Tue, 25 Jan 2022 09:41:10:  [1. 1. 1.]
# INFO  @ Tue, 25 Jan 2022 09:41:10:  [1. 1. 0.]
# INFO  @ Tue, 25 Jan 2022 09:41:10:  [1. 1. 1.]
# INFO  @ Tue, 25 Jan 2022 09:41:10:  [1. 1. 1.]]
# INFO  @ Tue, 25 Jan 2022 09:41:10: Beta labels:baseline,common,drug
# INFO  @ Tue, 25 Jan 2022 09:41:10: Included samples:Plasmid,BT16_DMSO,BT16_Palbo,BT16_Abema,CHLA06_DMSO,CHLA06_Palbo,CHLA06_Abema
# ...

# %%
ls
# Out:
# Book11.xlsx
# Brunello_corrected_counts.txt*
# Brunello_corrected_counts.xlsx
# Brunello_corrected_counts_BT16.txt*
# Brunello_corrected_counts_CHLA06.txt*
# Brunello_raw_counts.txt*
# Design_matrix_BT16_Drugs_vs_DMSO.txt*
# Design_matrix_BT16_drug_common_vs_DMSO.txt
# Design_matrix_CHLA06_drug_common_vs_DMSO.txt
# Design_matrix_CHLA06_drug_vs_DMSO.txt*
# Design_matrix_common_drugshared.txt
# Design_matrix_normal.txt*
# MAGeCK MLE Brunello Resistance.ipynb
# Results_corrected_counts_Drugs_vs_DMSO_design/
# Results_corrected_counts_common_shared/
# Results_corrected_counts_normal_design/
# Results_uncorrected_raw_counts_normal_design/
# control_sgRNA.txt*

# %%
# !mageck mle -k Brunello_corrected_counts_BT16.txt -d Design_matrix_BT16_drug_common_vs_DMSO.txt --control-sgrna control_sgRNA.txt --norm-method none
# Out:
# INFO  @ Fri, 08 Apr 2022 11:16:15: Parameters: /Users/lab/opt/anaconda3/bin/mageck mle -k Brunello_corrected_counts_BT16.txt -d Design_matrix_BT16_drug_common_vs_DMSO.txt --control-sgrna control_sgRNA.txt --norm-method none
# INFO  @ Fri, 08 Apr 2022 11:16:15: Cannot parse design matrix as a string; try to parse it as a file name ...
# INFO  @ Fri, 08 Apr 2022 11:16:15: Design matrix:
# INFO  @ Fri, 08 Apr 2022 11:16:15: [[1. 0.]
# INFO  @ Fri, 08 Apr 2022 11:16:15:  [1. 1.]
# INFO  @ Fri, 08 Apr 2022 11:16:15:  [1. 1.]]
# INFO  @ Fri, 08 Apr 2022 11:16:15: Beta labels:baseline,BT16_drug_common
# INFO  @ Fri, 08 Apr 2022 11:16:15: Included samples:BT16_DMSO,BT16_Palbo,BT16_Abema
# INFO  @ Fri, 08 Apr 2022 11:16:15: Loaded samples:BT16_DMSO;BT16_Palbo;BT16_Abema
# INFO  @ Fri, 08 Apr 2022 11:16:15: Sample index: 0;1;2
# INFO  @ Fri, 08 Apr 2022 11:16:15: Loaded 19105 genes.
# INFO  @ Fri, 08 Apr 2022 11:16:15: 3574 out of 3594 control sgRNAs are found in count table.
# ...

# %%
# !mageck mle -k Brunello_corrected_counts_CHLA06.txt -d Design_matrix_CHLA06_drug_common_vs_DMSO.txt --control-sgrna control_sgRNA.txt --norm-method none
# Out:
# INFO  @ Fri, 08 Apr 2022 11:26:47: Parameters: /Users/lab/opt/anaconda3/bin/mageck mle -k Brunello_corrected_counts_CHLA06.txt -d Design_matrix_CHLA06_drug_common_vs_DMSO.txt --control-sgrna control_sgRNA.txt --norm-method none
# INFO  @ Fri, 08 Apr 2022 11:26:48: Cannot parse design matrix as a string; try to parse it as a file name ...
# INFO  @ Fri, 08 Apr 2022 11:26:48: Design matrix:
# INFO  @ Fri, 08 Apr 2022 11:26:48: [[1. 0.]
# INFO  @ Fri, 08 Apr 2022 11:26:48:  [1. 1.]
# INFO  @ Fri, 08 Apr 2022 11:26:48:  [1. 1.]]
# INFO  @ Fri, 08 Apr 2022 11:26:48: Beta labels:baseline,CHLA06_drug_common
# INFO  @ Fri, 08 Apr 2022 11:26:48: Included samples:CHLA06_DMSO,CHLA06_Palbo,CHLA06_Abema
# INFO  @ Fri, 08 Apr 2022 11:26:48: Loaded samples:CHLA06_DMSO;CHLA06_Palbo;CHLA06_Abema
# INFO  @ Fri, 08 Apr 2022 11:26:48: Sample index: 0;1;2
# INFO  @ Fri, 08 Apr 2022 11:26:48: Loaded 19105 genes.
# ...

# %%
ls
# Out:
# Book11.xlsx
# Brunello_corrected_counts.txt*
# Brunello_corrected_counts.xlsx
# Brunello_corrected_counts_BT16.txt*
# Brunello_corrected_counts_BT16_drugs_and_plasmid.txt
# Brunello_corrected_counts_CHLA06.txt*
# Brunello_raw_counts.txt*
# Design_matrix_BT16_Drugs_vs_DMSO.txt*
# Design_matrix_BT16_drug_common_vs_DMSO.txt
# Design_matrix_BT16_drug_common_vs_plasmid.txt
# Design_matrix_CHLA06_drug_common_vs_DMSO.txt
# Design_matrix_CHLA06_drug_vs_DMSO.txt*
# Design_matrix_common_drugshared.txt
# Design_matrix_normal.txt*
# MAGeCK MLE Brunello Resistance.ipynb
# Results_corrected_counts_Drugs_vs_DMSO_design/
# Results_corrected_counts_cell_line_drug_common_vs_DMSO/
# Results_corrected_counts_cell_line_drug_common_vs_Plasmid/
# Results_corrected_counts_common_shared/
# Results_corrected_counts_normal_design/
# Results_uncorrected_raw_counts_normal_design/
# control_sgRNA.txt*

# %%
# !mageck mle -k Brunello_corrected_counts_BT16_drugs_and_plasmid.txt -d Design_matrix_BT16_drug_common_vs_plasmid.txt --control-sgrna control_sgRNA.txt --norm-method none
# Out:
# INFO  @ Thu, 19 May 2022 14:14:37: Parameters: /Users/lab/opt/anaconda3/bin/mageck mle -k Brunello_corrected_counts_BT16_drugs_and_plasmid.txt -d Design_matrix_BT16_drug_common_vs_plasmid.txt --control-sgrna control_sgRNA.txt --norm-method none
# INFO  @ Thu, 19 May 2022 14:14:39: Cannot parse design matrix as a string; try to parse it as a file name ...
# INFO  @ Thu, 19 May 2022 14:14:39: Design matrix:
# INFO  @ Thu, 19 May 2022 14:14:39: [[1. 0.]
# INFO  @ Thu, 19 May 2022 14:14:39:  [1. 1.]
# INFO  @ Thu, 19 May 2022 14:14:39:  [1. 1.]]
# INFO  @ Thu, 19 May 2022 14:14:39: Beta labels:baseline,BT16_drug_common
# INFO  @ Thu, 19 May 2022 14:14:39: Included samples:Plasmid,BT16_Palbo,BT16_Abema
# INFO  @ Thu, 19 May 2022 14:14:39: Loaded samples:Plasmid;BT16_Palbo;BT16_Abema
# INFO  @ Thu, 19 May 2022 14:14:39: Sample index: 0;1;2
# INFO  @ Thu, 19 May 2022 14:14:39: Loaded 19105 genes.
# INFO  @ Thu, 19 May 2022 14:14:39: 3574 out of 3594 control sgRNAs are found in count table.
# ...

# %%
# !mageck mle -k Brunello_corrected_counts_CHLA06_drugs_and_plasmid.txt -d Design_matrix_CHLA06_drug_common_vs_plasmid.txt --control-sgrna control_sgRNA.txt --norm-method none
# Out:
# INFO  @ Thu, 19 May 2022 14:29:41: Parameters: /Users/lab/opt/anaconda3/bin/mageck mle -k Brunello_corrected_counts_CHLA06_drugs_and_plasmid.txt -d Design_matrix_CHLA06_drug_common_vs_plasmid.txt --control-sgrna control_sgRNA.txt --norm-method none
# INFO  @ Thu, 19 May 2022 14:29:42: Cannot parse design matrix as a string; try to parse it as a file name ...
# INFO  @ Thu, 19 May 2022 14:29:42: Design matrix:
# INFO  @ Thu, 19 May 2022 14:29:42: [[1. 0.]
# INFO  @ Thu, 19 May 2022 14:29:42:  [1. 1.]
# INFO  @ Thu, 19 May 2022 14:29:42:  [1. 1.]]
# INFO  @ Thu, 19 May 2022 14:29:42: Beta labels:baseline,BT16_drug_common
# INFO  @ Thu, 19 May 2022 14:29:42: Included samples:Plasmid,CHLA06_Palbo,CHLA06_Abema
# INFO  @ Thu, 19 May 2022 14:29:42: Loaded samples:Plasmid;CHLA06_Palbo;CHLA06_Abema
# INFO  @ Thu, 19 May 2022 14:29:42: Sample index: 0;1;2
# INFO  @ Thu, 19 May 2022 14:29:42: Loaded 19105 genes.
# ...
